# %% [markdown]
# # EEG Config Sweep Notebook
# Define your configs in **Cell 2**, run all cells, compare results at the bottom.

# %%
# ── Imports ──────────────────────────────────────────────────────────────────
import os, warnings, itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from matplotlib.colors import LinearSegmentedColormap
import seaborn as sns
from IPython.display import display
from picard import picard
# Import everything from your refactored pipeline
from eeg_experiment import (
    ExperimentConfig,
    load_all_subjects,
    evaluate_all,
)

warnings.filterwarnings('ignore')
# %matplotlib inline
plt.rcParams.update({
    'figure.dpi': 120,
    'font.family': 'monospace',
    'axes.spines.top': False,
    'axes.spines.right': False,
})
print(' Imported ')
# Out:
#  Imported

# %% [markdown]
# ## 🔧 Define Your Configs Here
# Add as many `ExperimentConfig(...)` entries as you like. Give each a short `name`.

# %%
name = 'ICAnew_1.0w_0.8ov_5class'

# %%
SWEEP = [
    # {
    #     'name': 'ICA_norm',
    #     'config': ExperimentConfig(
    #         time_window=1.5,
    #         overlap_factor=0.8,
    #         l_freq=2.0,
    #         h_freq=80.0,
    #         apply_ica=True,
    #         cov_estimator='oas',
    #         ts_metric='riemann',
    #         classifiers=['logreg', 'svm'],
    #     )
    # },
    {
        'name': 'ICA_new_1.0w_0.8ov',
        'config': ExperimentConfig(
            time_window=1.0,
            overlap_factor=0.8,
            l_freq=5.0,
            h_freq=30.0,
            apply_ica=True,
            cov_estimator='oas',
            ts_metric='riemann',
            classifiers=['logreg', 'svm'],
        
        )
    },
    # {
    #     'name': 'NO_ICA_1.0w_0.80v',
    #     'config': ExperimentConfig(
    #         time_window=1.0,
    #         overlap_factor=0.8,
    #         l_freq=5.0,
    #         h_freq=30.0,
    #         apply_ica=False,
    #         cov_estimator='oas',
    #         ts_metric='riemann',
    #         classifiers=['logreg', 'svm'],
    #     )
    # },
]

print(f'Sweep defined: {len(SWEEP)} configs')
for entry in SWEEP:
    c = entry['config']
    print(f"  [{entry['name']}]  tw={c.time_window}s  overlap={c.overlap_factor}  "
          f"ica={c.apply_ica}  band={c.l_freq}-{c.h_freq}Hz  "
          f"cov={c.cov_estimator}  ts={c.ts_metric}  clfs={c.classifiers}")
# Out:
# Sweep defined: 1 configs
#   [ICA_new_1.0w_0.8ov]  tw=1.0s  overlap=0.8  ica=True  band=5.0-30.0Hz  cov=oas  ts=riemann  clfs=['logreg', 'svm']

# %% [markdown]
# ## ▶️ Run the Sweep
# Loads data once per config (ICA is the slow part). Results stored in `RESULTS`.

# %%
RESULTS = []   # list of dicts: {name, config, acc_dict}

for entry in SWEEP:
    name   = entry['name']
    config = entry['config']
    print(f'\n{"="*55}\n🚀  Running config: {name}\n{"="*55}')

    # suppress per-config confusion matrix plots — we'll make our own below
    config.show_plots = False
    config.save_confusion_matrices = False

    total_data, test_data = load_all_subjects(config)
    acc_dict = evaluate_all(total_data, test_data, config)

    # Also keep raw predictions for confusion matrices
    pred_store = {}
    from eeg_experiment import riemannian_predict
    for clf_type in config.classifiers:
        pred_store[clf_type] = {}
        for subject in total_data:
            if subject not in test_data:
                continue
            y_pred = riemannian_predict(
                total_data[subject]['data'], total_data[subject]['labels'],
                test_data[subject]['data'],  clf_type, config
            )
            pred_store[clf_type][subject] = {
                'y_true': test_data[subject]['labels'],
                'y_pred': y_pred,
            }

    RESULTS.append({
        'name':       name,
        'config':     config,
        'acc_dict':   acc_dict,
        'pred_store': pred_store,
    })
    print(f'✅  Done: {name}')

print('\n🏁 All configs finished.')
# Out:
# =======================================================
# 🚀  Running config: ICA_new_1.0w_0.8ov
# =======================================================
# Found 15 subjects: ['S116', 'S118', 'S5', 'S2', 'S119', 'S117', 'S3', 'S4', 'S2_', 'S1_', 'S1', 'S6', 'S115', 'S113', 'S114']
#
# ========================================
# Processing S116
#   [1] VI_S6_S1_B3__20251116_110436.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [2] VI_SX_S2_B1_1__20260315_022327.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S6_S1_B1__20251116_104819.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: []
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [4] VI_SX_S2_B2_2__20260315_023302.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 2]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 2]
#   ✅ ICA done. Channels: 100
#   [5] VI_SX_S2_B3_3__20260315_024046.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [6] VI_S6_S1_B2__20251116_105637.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S118
#   [1] VI_S8_S1_B1__20251119_052228.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0, 9]
#   Excluding 2/25 components: [0, 9]
#   ✅ ICA done. Channels: 100
#   [2] VI_S8_S1_B2__20251119_053014.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S8_S1_B3__20251119_053757.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S5
#   [1] S5_S1_B3_1654_161025_20251016_045503.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [2] S5_S1_B1_1640_161025_20251016_044052.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0, 1]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] S5_S1_B2_1646_161025_20251016_044828.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S2
#   [1] VI_S2_S1_B1_1800_08102025_20251008_060230.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0, 3]
#   Excluding 2/25 components: [0, 3]
#   ✅ ICA done. Channels: 100
#   [2] VI_S2_S1_B3_1825_08102025_20251008_062216.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S2_S1_B2_1810_08102025_20251008_061321.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0, 1]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S119
#   [1] VI_S9_S1_B2__20251119_062424.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [2] VI_S9_S1_B3__20251119_063405.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S9_S1_B1__20251119_060527.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S117
#   [1] VI_S7_S1_B3__20251118_120214.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [2] VI_S7_S1_B2__20251118_115409.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S7_S1_B1__20251118_114517.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S3
#   [1] S3_S1_B2_1445_131025_20251013_025010.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [2] S3_S1_B3_1459_131025_20251013_030119.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [1, 0]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] dummy_20251013_023702.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S4
#   [1] S4_S1_B2_1550_161025_20251016_035813.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [2] S4_S1_B1_1540_161025_20251016_034622.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] S4_S1_B3_1605_161025_20251016_040603.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S2_
#   [1] VI_SY_S2_B1__20260315_032320.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [2] VI_S2_S1_B3_20251111_041547.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0, 1]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S2_S1_B1_20251111_034621.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [4] VI_S2_S1_B1_n_20251111_034806.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0, 1]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [5] VI_S2_S1_B2_20251111_040016.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0, 2]
#   Excluding 2/25 components: [0, 2]
#   ✅ ICA done. Channels: 100
#   [6] VI_SY_S2_B3__20260315_034155.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 3]
#   EOG_horizontal: [0, 3]
#   Excluding 2/25 components: [0, 3]
#   ✅ ICA done. Channels: 100
#   [7] VI_SY_S2_B3__20260315_033301.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0, 1]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S1_
#   [1] VI_S1_S1_B1_20251110_120112.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0, 21]
#   Excluding 2/25 components: [0, 21]
#   ✅ ICA done. Channels: 100
#   [2] VI_S1_S1_B2_20251110_121030.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S1_S1_B3_20251110_122010.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S1
#   [1] VI_C_S1_S1_B4_1730_081025_20251008_053045.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [2] VI_S1_S1_B3_1720_081025_20251008_052324.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0, 1]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S1_S1_B2_1710_081025_20251008_051501.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [4] VI_S1_S1_B1_1700_08102025_20251008_050540.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: []
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S6
#   [1] VI_S6_S1_B1_1401_251025_20251025_020734.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [1, 0]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [2] VI_S6_S1_B2_1415_251025_20251025_021420.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: []
#   EOG_horizontal: [0, 2]
#   Excluding 2/25 components: [0, 2]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S6_S1_B3_1422_251025_20251025_022100.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: []
#   EOG_horizontal: [0, 2]
#   Excluding 2/25 components: [0, 2]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S115
#   [1] VI_S5_S1_B2__20251114_040445.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   [2] VI_S5_S1_B1__20251114_035449.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: []
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S5_S1_B3_20251114_041311.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S113
#   [1] VI_S13_S1_B2_20251114_115832.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   [2] VI_S13_S1_B1__20251114_114825.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S13_S1_B3__20251114_120748.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0]
#   EOG_horizontal: [0]
#   Excluding 1/25 components: [0]
#   ✅ ICA done. Channels: 100
#
# ========================================
# Processing S114
#   [1] VI_S4_S1_B2__20251114_025912.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 3]
#   EOG_horizontal: [0, 3]
#   Excluding 2/25 components: [0, 3]
#   ✅ ICA done. Channels: 100
#   [2] VI__20251114_024930.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
#   Splitting block 2 → last trial → test set
#   [3] VI_S4_S1_B3__20251114_030805.mff
# 🔧 ICA: 25 components on 100 channels …
#   EOG_vertical: [0, 1]
#   EOG_horizontal: [0]
#   Excluding 2/25 components: [0, 1]
#   ✅ ICA done. Channels: 100
# S116: train (1360, 100, 500) | classes {0: 272, 1: 272, 2: 272, 3: 272, 4: 272}
# S118: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S5: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S2: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S119: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S117: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S3: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S4: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S2_: train (1360, 100, 500) | classes {0: 272, 1: 272, 2: 272, 3: 272, 4: 272}
# S1_: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S1: train (880, 100, 500) | classes {0: 176, 1: 176, 2: 176, 3: 176, 4: 176}
# S6: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S115: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S113: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
# S114: train (640, 100, 500) | classes {0: 128, 1: 128, 2: 128, 3: 128, 4: 128}
#
# ──────────────────────────────────────────────────
# Classifier: LOGREG
# ──────────────────────────────────────────────────
#   S116 — train 1360 | test 80
#   Accuracy: 0.3375
#   S118 — train 640 | test 80
#   Accuracy: 0.3250
#   S5 — train 640 | test 80
#   Accuracy: 0.3500
#   S2 — train 640 | test 80
#   Accuracy: 0.5750
#   S119 — train 640 | test 80
#   Accuracy: 0.4500
#   S117 — train 640 | test 80
#   Accuracy: 0.1250
#   S3 — train 640 | test 80
#   Accuracy: 0.3500
#   S4 — train 640 | test 80
#   Accuracy: 0.3250
#   S2_ — train 1360 | test 80
#   Accuracy: 0.3125
#   S1_ — train 640 | test 80
#   Accuracy: 0.5000
#   S1 — train 880 | test 80
#   Accuracy: 0.3250
#   S6 — train 640 | test 80
#   Accuracy: 0.4500
#   S115 — train 640 | test 80
#   Accuracy: 0.2625
#   S113 — train 640 | test 80
#   Accuracy: 0.2000
#   S114 — train 640 | test 80
#   Accuracy: 0.2250
#
# ──────────────────────────────────────────────────
# Classifier: SVM
# ──────────────────────────────────────────────────
#   S116 — train 1360 | test 80
#   Accuracy: 0.3125
#   S118 — train 640 | test 80
#   Accuracy: 0.3000
#   S5 — train 640 | test 80
#   Accuracy: 0.3750
#   S2 — train 640 | test 80
#   Accuracy: 0.5625
#   S119 — train 640 | test 80
#   Accuracy: 0.3625
#   S117 — train 640 | test 80
#   Accuracy: 0.0875
#   S3 — train 640 | test 80
#   Accuracy: 0.2875
#   S4 — train 640 | test 80
#   Accuracy: 0.5125
#   S2_ — train 1360 | test 80
#   Accuracy: 0.3125
#   S1_ — train 640 | test 80
#   Accuracy: 0.5250
#   S1 — train 880 | test 80
#   Accuracy: 0.3250
#   S6 — train 640 | test 80
#   Accuracy: 0.3875
#   S115 — train 640 | test 80
#   Accuracy: 0.3000
#   S113 — train 640 | test 80
#   Accuracy: 0.2000
#   S114 — train 640 | test 80
#   Accuracy: 0.2500
#
# ==================================================
# SUMMARY
# ==================================================
# Subject         logreg       svm
# ────────────────────────────────
# S1              0.3250    0.3250
# S113            0.2000    0.2000
# S114            0.2250    0.2500
# S115            0.2625    0.3000
# S116            0.3375    0.3125
# S117            0.1250    0.0875
# S118            0.3250    0.3000
# S119            0.4500    0.3625
# S1_             0.5000    0.5250
# S2              0.5750    0.5625
# S2_             0.3125    0.3125
# S3              0.3500    0.2875
# S4              0.3250    0.5125
# S5              0.3500    0.3750
# S6              0.4500    0.3875
# ✅  Done: ICA_new_1.0w_0.8ov
#
# 🏁 All configs finished.

# %% [markdown]
# ## 📊 Summary Table

# %%
# Build a flat DataFrame: rows = (config, classifier, subject), col = accuracy
rows = []
for res in RESULTS:
    for clf_type, subj_acc in res['acc_dict'].items():
        for subject, acc in subj_acc.items():
            rows.append({
                'config':     res['name'],
                'classifier': clf_type,
                'subject':    subject,
                'accuracy':   acc,
            })

df = pd.DataFrame(rows)

# Pivot: configs × classifiers as columns, subjects as rows
df['run'] = df['config'] + ' / ' + df['classifier']
pivot = df.pivot_table(index='subject', columns='run', values='accuracy')

# Append a mean row
pivot.loc['MEAN'] = pivot.mean()

# Style: highlight best in each row
styled = (
    pivot.style
    .format('{:.3f}')
    .highlight_max(axis=1, color='#c6efce')   # green = best per row
    .highlight_min(axis=1, color='#ffc7ce')   # red   = worst per row
    .set_caption('Accuracy by Subject × Config/Classifier  |  green=best  red=worst')
)
display(styled)

# Also save as CSV
csv_path = f'{name}sweep_results.csv'
pivot.to_csv(csv_path)
print(f'\n📁 Saved to {csv_path}')
# Out:
# <style type="text/css">
# #T_f65f7_row0_col0, #T_f65f7_row0_col1, #T_f65f7_row1_col0, #T_f65f7_row1_col1, #T_f65f7_row10_col0, #T_f65f7_row10_col1 {
#   background-color: #c6efce;
#   background-color: #ffc7ce;
# }
# #T_f65f7_row2_col0, #T_f65f7_row3_col0, #T_f65f7_row4_col1, #T_f65f7_row5_col1, #T_f65f7_row6_col1, #T_f65f7_row7_col1, #T_f65f7_row8_col0, #T_f65f7_row9_col1, #T_f65f7_row11_col1, #T_f65f7_row12_col0, #T_f65f7_row13_col0, #T_f65f7_row14_col1, #T_f65f7_row15_col1 {
#   background-color: #ffc7ce;
# }
# #T_f65f7_row2_col1, #T_f65f7_row3_col1, #T_f65f7_row4_col0, #T_f65f7_row5_col0, #T_f65f7_row6_col0, #T_f65f7_row7_col0, #T_f65f7_row8_col1, #T_f65f7_row9_col0, #T_f65f7_row11_col0, #T_f65f7_row12_col1, #T_f65f7_row13_col1, #T_f65f7_row14_col0, #T_f65f7_row15_col0 {
#   background-color: #c6efce;
# }
# </style>
# <table id="T_f65f7">
#   <caption>Accuracy by Subject × Config/Classifier  |  green=best  red=worst</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >run</th>
#       <th id="T_f65f7_level0_col0" class="col_heading level0 col0" >ICA_new_1.0w_0.8ov / logreg</th>
#       <th id="T_f65f7_level0_col1" class="col_heading level0 col1" >ICA_new_1.0w_0.8ov / svm</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >subject</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f65f7_level0_row0" class="row_heading level0 row0" >S1</th>
#       <td id="T_f65f7_row0_col0" class="data row0 col0" >0.325</td>
#       <td id="T_f65f7_row0_col1" class="data row0 col1" >0.325</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row1" class="row_heading level0 row1" >S113</th>
#       <td id="T_f65f7_row1_col0" class="data row1 col0" >0.200</td>
#       <td id="T_f65f7_row1_col1" class="data row1 col1" >0.200</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row2" class="row_heading level0 row2" >S114</th>
#       <td id="T_f65f7_row2_col0" class="data row2 col0" >0.225</td>
#       <td id="T_f65f7_row2_col1" class="data row2 col1" >0.250</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row3" class="row_heading level0 row3" >S115</th>
#       <td id="T_f65f7_row3_col0" class="data row3 col0" >0.263</td>
#       <td id="T_f65f7_row3_col1" class="data row3 col1" >0.300</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row4" class="row_heading level0 row4" >S116</th>
#       <td id="T_f65f7_row4_col0" class="data row4 col0" >0.338</td>
#       <td id="T_f65f7_row4_col1" class="data row4 col1" >0.312</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row5" class="row_heading level0 row5" >S117</th>
#       <td id="T_f65f7_row5_col0" class="data row5 col0" >0.125</td>
#       <td id="T_f65f7_row5_col1" class="data row5 col1" >0.087</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row6" class="row_heading level0 row6" >S118</th>
#       <td id="T_f65f7_row6_col0" class="data row6 col0" >0.325</td>
#       <td id="T_f65f7_row6_col1" class="data row6 col1" >0.300</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row7" class="row_heading level0 row7" >S119</th>
#       <td id="T_f65f7_row7_col0" class="data row7 col0" >0.450</td>
#       <td id="T_f65f7_row7_col1" class="data row7 col1" >0.362</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row8" class="row_heading level0 row8" >S1_</th>
#       <td id="T_f65f7_row8_col0" class="data row8 col0" >0.500</td>
#       <td id="T_f65f7_row8_col1" class="data row8 col1" >0.525</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row9" class="row_heading level0 row9" >S2</th>
#       <td id="T_f65f7_row9_col0" class="data row9 col0" >0.575</td>
#       <td id="T_f65f7_row9_col1" class="data row9 col1" >0.562</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row10" class="row_heading level0 row10" >S2_</th>
#       <td id="T_f65f7_row10_col0" class="data row10 col0" >0.312</td>
#       <td id="T_f65f7_row10_col1" class="data row10 col1" >0.312</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row11" class="row_heading level0 row11" >S3</th>
#       <td id="T_f65f7_row11_col0" class="data row11 col0" >0.350</td>
#       <td id="T_f65f7_row11_col1" class="data row11 col1" >0.287</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row12" class="row_heading level0 row12" >S4</th>
#       <td id="T_f65f7_row12_col0" class="data row12 col0" >0.325</td>
#       <td id="T_f65f7_row12_col1" class="data row12 col1" >0.512</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row13" class="row_heading level0 row13" >S5</th>
#       <td id="T_f65f7_row13_col0" class="data row13 col0" >0.350</td>
#       <td id="T_f65f7_row13_col1" class="data row13 col1" >0.375</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row14" class="row_heading level0 row14" >S6</th>
#       <td id="T_f65f7_row14_col0" class="data row14 col0" >0.450</td>
#       <td id="T_f65f7_row14_col1" class="data row14 col1" >0.388</td>
#     </tr>
#     <tr>
#       <th id="T_f65f7_level0_row15" class="row_heading level0 row15" >MEAN</th>
#       <td id="T_f65f7_row15_col0" class="data row15 col0" >0.341</td>
#       <td id="T_f65f7_row15_col1" class="data row15 col1" >0.340</td>
#     </tr>
#   </tbody>
# </table>
# 📁 Saved to ICA_new_1.0w_0.8ovsweep_results.csv

# %% [markdown]
# ## 📈 Accuracy Bar Charts — Per Subject

# %%
subjects  = sorted(df['subject'].unique())
runs      = sorted(df['run'].unique())
palette   = sns.color_palette('tab10', n_colors=len(runs))
color_map = dict(zip(runs, palette))

n_subj = len(subjects)
ncols  = min(3, n_subj)
nrows  = (n_subj + ncols - 1) // ncols

fig, axes = plt.subplots(nrows, ncols,
                          figsize=(5 * ncols, 4 * nrows),
                          sharey=True)
axes_flat = np.array(axes).flatten()

chance = 1 / len(RESULTS[0]['config'].classes)

for i, subj in enumerate(subjects):
    ax   = axes_flat[i]
    sdf  = df[df['subject'] == subj].set_index('run')['accuracy'].reindex(runs)
    bars = ax.bar(range(len(runs)), sdf.values,
                  color=[color_map[r] for r in runs],
                  edgecolor='white', linewidth=0.8, zorder=3)

    # Chance line
    ax.axhline(chance, color='grey', linestyle='--', linewidth=1,
               label=f'chance ({chance:.2f})', zorder=2)

    # Value labels
    for bar, val in zip(bars, sdf.values):
        if not np.isnan(val):
            ax.text(bar.get_x() + bar.get_width() / 2, val + 0.01,
                    f'{val:.2f}', ha='center', va='bottom', fontsize=7)

    ax.set_title(subj, fontweight='bold')
    ax.set_xticks(range(len(runs)))
    ax.set_xticklabels([r.replace(' / ', '\n') for r in runs],
                        fontsize=7, rotation=0)
    ax.set_ylim(0, 1.05)
    ax.set_ylabel('Accuracy')
    ax.yaxis.grid(True, alpha=0.4, zorder=0)

# Hide unused axes
for j in range(i + 1, len(axes_flat)):
    axes_flat[j].set_visible(False)

# Legend (one per run/colour)
handles = [plt.Rectangle((0,0),1,1, color=color_map[r]) for r in runs]
fig.legend(handles, runs, loc='lower center', ncol=len(runs),
           fontsize=8, frameon=False, bbox_to_anchor=(0.5, -0.02))

fig.suptitle('Per-Subject Accuracy Across Configs & Classifiers',
              fontsize=13, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(f'{type}{name}_accuracy_by_subject.png', bbox_inches='tight', dpi=150)
plt.show()
print('📁 Saved accuracy_by_subject.png')
# Out:
# 📁 Saved accuracy_by_subject.png

# %% [markdown]
# ## 🔲 Confusion Matrices — Side by Side
# One row per subject, one column per (config × classifier) run.

# %%
from sklearn.metrics import confusion_matrix

# Build list of all (config_name, clf_type) combos in order
runs_list = [
    (res['name'], clf_type)
    for res in RESULTS
    for clf_type in res['config'].classifiers
]

class_names = RESULTS[0]['config'].classes
n_cols = len(runs_list)
n_rows = len(subjects)

fig, axes = plt.subplots(n_rows, n_cols,
                          figsize=(3.5 * n_cols, 3.2 * n_rows))

# Ensure 2D even with 1 row or 1 col
if n_rows == 1: axes = axes[np.newaxis, :]
if n_cols == 1: axes = axes[:, np.newaxis]

cmap = LinearSegmentedColormap.from_list('eeg_blues', ['#f7fbff', '#08519c'])

for row_i, subj in enumerate(subjects):
    for col_j, (cfg_name, clf_type) in enumerate(runs_list):
        ax = axes[row_i, col_j]

        # Find matching result
        res  = next(r for r in RESULTS if r['name'] == cfg_name)
        preds = res['pred_store'].get(clf_type, {}).get(subj)

        if preds is None:
            ax.text(0.5, 0.5, 'N/A', ha='center', va='center',
                    transform=ax.transAxes)
            ax.axis('off')
            continue

        cm  = confusion_matrix(preds['y_true'], preds['y_pred'], normalize='true')
        acc = np.diag(cm).mean()

        im = ax.imshow(cm, vmin=0, vmax=1, cmap=cmap, aspect='auto')

        # Cell text
        for r in range(len(class_names)):
            for c in range(len(class_names)):
                ax.text(c, r, f'{cm[r, c]:.2f}',
                        ha='center', va='center', fontsize=8,
                        color='white' if cm[r, c] > 0.6 else 'black')

        ax.set_xticks(range(len(class_names)))
        ax.set_yticks(range(len(class_names)))
        ax.set_xticklabels(class_names, fontsize=7)
        ax.set_yticklabels(class_names if col_j == 0 else [], fontsize=7)

        if row_i == 0:
            ax.set_title(f'{cfg_name}\n{clf_type}', fontsize=8, fontweight='bold')
        if col_j == 0:
            ax.set_ylabel(subj, fontsize=9, fontweight='bold')

        ax.set_xlabel(f'acc={acc:.2f}', fontsize=7)

fig.suptitle('Confusion Matrices  |  rows=subjects  cols=config/classifier',
              fontsize=12, fontweight='bold', y=1.01)
plt.tight_layout()
plt.savefig(f'{type}{name}_confusion_matrices_grid.png', bbox_inches='tight', dpi=150)
plt.show()
print('📁 Saved confusion_matrices_grid.png')
# Out:
# 📁 Saved confusion_matrices_grid.png

# %% [markdown]
# ## 🏆 Overall Mean Accuracy — Quick Comparison

# %%
mean_acc = df.groupby('run')['accuracy'].agg(['mean', 'std']).sort_values('mean', ascending=False)
mean_acc.columns = ['mean_acc', 'std_acc']

fig, ax = plt.subplots(figsize=(max(6, len(mean_acc) * 1.4), 4))
colors = sns.color_palette('RdYlGn', n_colors=len(mean_acc))

bars = ax.barh(mean_acc.index, mean_acc['mean_acc'],
               xerr=mean_acc['std_acc'], color=colors,
               edgecolor='white', linewidth=0.8,
               error_kw=dict(elinewidth=1.2, capsize=4))

ax.axvline(chance, color='grey', linestyle='--', linewidth=1.2,
           label=f'chance ({chance:.2f})')

for bar, (_, row) in zip(bars, mean_acc.iterrows()):
    ax.text(row['mean_acc'] + row['std_acc'] + 0.005,
            bar.get_y() + bar.get_height() / 2,
            f"{row['mean_acc']:.3f} ± {row['std_acc']:.3f}",
            va='center', fontsize=9)

ax.set_xlabel('Mean Accuracy (across subjects)')
ax.set_title('Overall Ranking — Config / Classifier', fontweight='bold')
ax.set_xlim(0, 1.1)
ax.legend()
ax.xaxis.grid(True, alpha=0.4)
plt.tight_layout()
plt.savefig(f'{type}_{name}_overall_ranking.png', bbox_inches='tight', dpi=150)
plt.show()
print('📁 Saved overall_ranking.png')
# Out:
# 📁 Saved overall_ranking.png

# %%
from sklearn.metrics import f1_score
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# ── Build per-class F1 for every (config, clf, subject) ──────────────────────
f1_rows = []
class_names = RESULTS[0]['config'].classes

for res in RESULTS:
    for clf_type, subj_preds in res['pred_store'].items():
        for subject, preds in subj_preds.items():
            f1s = f1_score(preds['y_true'], preds['y_pred'],
                           average=None, labels=list(range(len(class_names))))
            for cls_i, cls_name in enumerate(class_names):
                f1_rows.append({
                    'run':     f"{res['name']} / {clf_type}",
                    'subject': subject,
                    'class':   cls_name,
                    'f1':      f1s[cls_i],
                })

df_f1 = pd.DataFrame(f1_rows)

# ── Heatmap: mean F1 per class across subjects, for each run ─────────────────
pivot_f1 = df_f1.groupby(['run', 'class'])['f1'].mean().unstack()   # rows=run, cols=class

fig, ax = plt.subplots(figsize=(len(class_names) * 1.8 + 2, len(pivot_f1) * 0.8 + 1.5))
sns.heatmap(pivot_f1, annot=True, fmt='.3f', vmin=0, vmax=1,
            cmap='YlGn', linewidths=0.5, ax=ax, cbar_kws={'label': 'F1'})
ax.set_title('Mean Per-Class F1  |  rows=config/clf  cols=class', fontweight='bold')
ax.set_ylabel('')
ax.set_xlabel('')
plt.tight_layout()
plt.savefig(f'{type}_{name}_f1_per_class.png', bbox_inches='tight', dpi=150)
plt.show()
print('📁 Saved f1_per_class.png')
# Out:
# 📁 Saved f1_per_class.png

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))

# 1. Draw the boxplot to show quartiles
sns.boxplot(data=df, x='accuracy', y='run', color='white', width=0.5)

# 2. Overlay the actual data points so you can see the 0.145 value
sns.stripplot(data=df, x='accuracy', y='run', color='black', alpha=0.6, size=6)

plt.axvline(0.2, color='red', linestyle='--', label='Chance (0.3)')
plt.title('Accuracy Distribution per Run')
plt.grid(axis='x', alpha=0.3)
plt.savefig(f"{name}_accuracy_dist.png")
plt.show()
